# %%
print("Hello world")
# Out:
# Hello world

# %%
import nltk

# %%
## Removing punctuation from the string 



string ="The region has seen a number of major terror attacks which were mentioned during the address. These included the 2019 Colombo attacks, the 2019 Pulwama terror attack perpetrated by Jaish E Mohammed, the 2020 Gurudwara attack in Kabul by IS-Khorasan, 2021 Kabul airport attack. The Committee has held an informal meeting on community engagement to counter-terrorism in South and South-East Asia in June 2018.Indian envoy to UN T. S. Tirumurti was appointed the chair of the key UNSC committee on January 13, 2022 for a period of one year. The committee is tasked with undertaking steps like criminalizing financing of terrorism, sharing information with governments planning terror acts, etc. During the address, he also raised the issue of misuse of information and communications technologies (ICT) and use of drones for cross-border trafficking of arms, drugs and launching terror attacks which remain an issue of serious concern.Tirumurti in the capacity of the Indian envoy to the UN also paid homage to the Indian security personnel who died in the Pulwama terror attack 3 years ago on February 14, 2019."


for i in string:
    if (i=="-" or i =="." or i==","):
        string=string.replace(i," ")
    
    
print(string)
# Out:
# The region has seen a number of major terror attacks which were mentioned during the address  These included the 2019 Colombo attacks  the 2019 Pulwama terror attack perpetrated by Jaish E Mohammed  the 2020 Gurudwara attack in Kabul by IS Khorasan  2021 Kabul airport attack  The Committee has held an informal meeting on community engagement to counter terrorism in South and South East Asia in June 2018 Indian envoy to UN T  S  Tirumurti was appointed the chair of the key UNSC committee on January 13  2022 for a period of one year  The committee is tasked with undertaking steps like criminalizing financing of terrorism  sharing information with governments planning terror acts  etc  During the address  he also raised the issue of misuse of information and communications technologies (ICT) and use of drones for cross border trafficking of arms  drugs and launching terror attacks which remain an issue of serious concern Tirumurti in the capacity of the Indian envoy to the UN also paid 
# ...

# %%
### But in the case of bigger dataset we should always use the regex function 

import re

string ="The region has seen a number of major terror attacks which were mentioned during the address. These included the 2019 Colombo attacks, the 2019 Pulwama terror attack perpetrated by Jaish E Mohammed, the 2020 Gurudwara attack in Kabul by IS-Khorasan, 2021 Kabul airport attack. The Committee has held an informal meeting on community engagement to counter-terrorism in South and South-East Asia in June 2018.Indian envoy to UN T. S. Tirumurti was appointed the chair of the key UNSC committee on January 13, 2022 for a period of one year. The committee is tasked with undertaking steps like criminalizing financing of terrorism, sharing information with governments planning terror acts, etc. During the address, he also raised the issue of misuse of information and communications technologies (ICT) and use of drones for cross-border trafficking of arms, drugs and launching terror attacks which remain an issue of serious concern.Tirumurti in the capacity of the Indian envoy to the UN also paid homage to the Indian security personnel who died in the Pulwama terror attack 3 years ago on February 14, 2019."

string = re.sub(r'[^\w\s]','',string)

print(string)
# Out:
# The region has seen a number of major terror attacks which were mentioned during the address These included the 2019 Colombo attacks the 2019 Pulwama terror attack perpetrated by Jaish E Mohammed the 2020 Gurudwara attack in Kabul by ISKhorasan 2021 Kabul airport attack The Committee has held an informal meeting on community engagement to counterterrorism in South and SouthEast Asia in June 2018Indian envoy to UN T S Tirumurti was appointed the chair of the key UNSC committee on January 13 2022 for a period of one year The committee is tasked with undertaking steps like criminalizing financing of terrorism sharing information with governments planning terror acts etc During the address he also raised the issue of misuse of information and communications technologies ICT and use of drones for crossborder trafficking of arms drugs and launching terror attacks which remain an issue of serious concernTirumurti in the capacity of the Indian envoy to the UN also paid homage to the Indian s
# ...

# %%
## Tokenisation of the given string

import nltk
nltk.download('punkt')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/pranavwadkar/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/pranavwadkar/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
print(string)
# Out:
# The region has seen a number of major terror attacks which were mentioned during the address These included the 2019 Colombo attacks the 2019 Pulwama terror attack perpetrated by Jaish E Mohammed the 2020 Gurudwara attack in Kabul by ISKhorasan 2021 Kabul airport attack The Committee has held an informal meeting on community engagement to counterterrorism in South and SouthEast Asia in June 2018Indian envoy to UN T S Tirumurti was appointed the chair of the key UNSC committee on January 13 2022 for a period of one year The committee is tasked with undertaking steps like criminalizing financing of terrorism sharing information with governments planning terror acts etc During the address he also raised the issue of misuse of information and communications technologies ICT and use of drones for crossborder trafficking of arms drugs and launching terror attacks which remain an issue of serious concernTirumurti in the capacity of the Indian envoy to the UN also paid homage to the Indian s
# ...

# %%
tokenised_string=nltk.word_tokenize(string)
print(tokenised_string)
# Out:
# ['The', 'region', 'has', 'seen', 'a', 'number', 'of', 'major', 'terror', 'attacks', 'which', 'were', 'mentioned', 'during', 'the', 'address', 'These', 'included', 'the', '2019', 'Colombo', 'attacks', 'the', '2019', 'Pulwama', 'terror', 'attack', 'perpetrated', 'by', 'Jaish', 'E', 'Mohammed', 'the', '2020', 'Gurudwara', 'attack', 'in', 'Kabul', 'by', 'ISKhorasan', '2021', 'Kabul', 'airport', 'attack', 'The', 'Committee', 'has', 'held', 'an', 'informal', 'meeting', 'on', 'community', 'engagement', 'to', 'counterterrorism', 'in', 'South', 'and', 'SouthEast', 'Asia', 'in', 'June', '2018Indian', 'envoy', 'to', 'UN', 'T', 'S', 'Tirumurti', 'was', 'appointed', 'the', 'chair', 'of', 'the', 'key', 'UNSC', 'committee', 'on', 'January', '13', '2022', 'for', 'a', 'period', 'of', 'one', 'year', 'The', 'committee', 'is', 'tasked', 'with', 'undertaking', 'steps', 'like', 'criminalizing', 'financing', 'of', 'terrorism', 'sharing', 'information', 'with', 'governments', 'planning', 'terror', 'acts', '
# ...

# %%
## Performing the word count operaiton on the set of the tokens here now

count =0
dict={}

##First we have to assign each of the tokens as the key pair in the dictionary


for i in tokenised_string:
    count+=1
    dict[i]=0
    
print(count)
print(dict)

## Now for creating the value of the word

word_count=0

for i in tokenised_string:
    word_count=0
    for j in tokenised_string:
        if(i == j):
            word_count+=1
            dict[i]=word_count

print(dict)
# Out:
# 178
# ...

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# %%
print(string)
# Out:
# The region has seen a number of major terror attacks which were mentioned during the address These included the 2019 Colombo attacks the 2019 Pulwama terror attack perpetrated by Jaish E Mohammed the 2020 Gurudwara attack in Kabul by ISKhorasan 2021 Kabul airport attack The Committee has held an informal meeting on community engagement to counterterrorism in South and SouthEast Asia in June 2018Indian envoy to UN T S Tirumurti was appointed the chair of the key UNSC committee on January 13 2022 for a period of one year The committee is tasked with undertaking steps like criminalizing financing of terrorism sharing information with governments planning terror acts etc During the address he also raised the issue of misuse of information and communications technologies ICT and use of drones for crossborder trafficking of arms drugs and launching terror attacks which remain an issue of serious concernTirumurti in the capacity of the Indian envoy to the UN also paid homage to the Indian s
# ...

# %%
basecloud =WordCloud().generate(string)
plt.imshow(basecloud)
plt.axis("off")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
wordcloud =WordCloud(relative_scaling=1.0).generate(string)
plt.imshow(wordcloud)
plt.axis("off")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
